# %%
import prepareData
import importlib
import convertParams
import paramRedux
import processGen
import dataFrameTools

# %%
importlib.reload(prepareData)
importlib.reload(convertParams)
importlib.reload(paramRedux)
prepareData.prepareData("clip_s")
# Out:
# Bike Models with Tandem and Extra Members Dropped in 12.958657503128052 seconds
#       SSSIDECX3  SSSIDECX2  SSSIDECX1  RACKFROM_TOP_OF_SEATSTAY offset  \
# 1          65.5      131.2      306.0                            -27.0
# 2          65.5      104.1      242.9                            -27.0
# 3          65.5      165.3      385.7                            -27.0
# 4          65.5      132.3      308.6                            -27.0
# 5          65.5      143.6      335.2                            -27.0
# ...         ...        ...        ...                              ...
# 4796       58.8      117.7      274.6                            -27.0
# 4797       65.5       75.8      189.4                            -27.0
# 4798       65.5      130.4      304.2                            -27.0
# 4799       88.9      177.7       10.3                            -27.0
# 4800       65.5      130.4      304.2                            -27.0
#
# ...
